# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 32.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 33.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 33.84]
}

df = pd.DataFrame(data)

# 绘制箱线图
plt.figure(figsize=(14, 8))
sns.boxplot(x='Alpha', y='CIFAR-10 AlexNet', hue='Method', data=df)
plt.title('CIFAR-10 (AlexNet) Performance under Different Alpha (Heterogeneity Levels)')
plt.xlabel('Alpha')
plt.ylabel('Performance')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.show()

# %%
# 绘制多个模型的表现，并使用子图展示每个模型的数据
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 32.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 33.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 33.84]
}

# 定义模型列
models = ['CIFAR-10 AlexNet', 'CIFAR-10 VGG-11', 'Fashion MNIST AlexNet', 'Fashion MNIST VGG-11', 'CIFAR-100 ResNet-18']

# 创建子图布局
fig, axes = plt.subplots(2, 3, figsize=(18, 10), sharex=True, sharey=False)
axes = axes.flatten()

# 为每个模型绘制箱线图
for i, model in enumerate(models):
    sns.boxplot(x='Alpha', y=model, hue='Method', data=df, palette="Set2", ax=axes[i])
    axes[i].set_title(f'{model} Performance', fontsize=14)
    axes[i].set_xlabel('Alpha (Heterogeneity Level)', fontsize=12)
    axes[i].set_ylabel('Performance', fontsize=12)
    axes[i].grid(True)
    if i == 0:
        axes[i].legend(loc='upper right', title="Method")
    else:
        axes[i].legend_.remove()

# 删除最后一个空子图框
fig.delaxes(axes[-1])

# 调整布局
plt.tight_layout()

# 显示图表
plt.show()

# %% [markdown]
# ## 有数据：9种方法，每种方法对应5组数据（模型），每组数据（模型）有3种alpha=0.1 ，0.2,0.3，现要分析异质性对模型的影响，说明我们的方法对于不同异构性都有较好的表现，该话什么统计图比较合适

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 32.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 33.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 33.84]
}

df = pd.DataFrame(data)

# 定义调色板
palette = sns.color_palette("tab10", n_colors=9)

# 定义模型列
models = ['CIFAR-10 AlexNet', 'CIFAR-10 VGG-11', 'Fashion MNIST AlexNet', 'Fashion MNIST VGG-11', 'CIFAR-100 ResNet-18']

# 创建子图布局
fig, axes = plt.subplots(2, 3, figsize=(18, 10), sharex=True, sharey=False)
axes = axes.flatten()

# 为每个模型绘制箱线图并添加线条，使颜色与图例对齐
for i, model in enumerate(models):
    sns.boxplot(x='Alpha', y=model, hue='Method', data=df, ax=axes[i], palette=palette)
    
    # 通过添加连线使趋势更加明显
    for method in df['Method'].unique():
        # 按照 Alpha 对应的顺序排序
        data_subset = df[df['Method'] == method].sort_values(by='Alpha')
        axes[i].plot(data_subset['Alpha'], data_subset[model], marker='o', label=method, color=palette[df['Method'].unique().tolist().index(method)], linestyle='--')
    
    axes[i].set_title(f'{model} Performance', fontsize=14)
    axes[i].set_xlabel('Alpha (Heterogeneity Level)', fontsize=12)
    axes[i].set_ylabel('Performance', fontsize=12)
    axes[i].grid(True)

# 设置图例在第一个子图中显示，并移除其他子图中的图例
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles[:9], labels[:9], loc='upper center', ncol=5, title="Method", bbox_to_anchor=(0.5, 1.05))

# 删除最后一个空子图框
fig.delaxes(axes[-1])

# 调整布局
plt.tight_layout()

# 显示图表
plt.show()

# %% [markdown]
# # 雷达图

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 32.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 33.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 33.84]
}

# 创建DataFrame
df = pd.DataFrame(data)

# 我们将以 'CIFAR-10 AlexNet' 为例来绘制雷达图
methods = df['Method'].unique()
alphas = df['Alpha'].unique()

# 准备绘制雷达图的数据
def prepare_radar_data(df, alpha, metric):
    df_alpha = df[df['Alpha'] == alpha]
    return df_alpha[metric].values

# 设置雷达图参数
metrics = ['CIFAR-10 AlexNet', 'CIFAR-10 VGG-11', 'Fashion MNIST AlexNet', 'Fashion MNIST VGG-11', 'CIFAR-100 ResNet-18']
num_metrics = len(metrics)

# 绘制雷达图
for alpha in alphas:
    values = []
    for method in methods:
        # 对于每个方法，获取该 alpha 下的值
        method_data = df[(df['Method'] == method) & (df['Alpha'] == alpha)]
        values.append(method_data[metrics].values.flatten())

    # 创建雷达图的角度
    angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
    angles += angles[:1]

    fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

    for idx, method_values in enumerate(values):
        method_values = method_values.tolist()
        method_values += method_values[:1]  # 将第一个值重复到最后以形成闭环
        ax.plot(angles, method_values, label=methods[idx], linewidth=2)
        ax.fill(angles, method_values, alpha=0.25)

    # 设置标签
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics)

    # 添加图例
    plt.legend(loc='upper right', bbox_to_anchor=(1.1, 1.1))

    plt.title(f'Performance of Methods at Alpha = {alpha}')
    plt.show()

# %% [markdown]
# ## 1、美化

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 33.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 34.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 34.84]
}

# 创建DataFrame
df = pd.DataFrame(data)

# 设置需要展示的性能指标
metrics = ['CIFAR-10 AlexNet', 'CIFAR-10 VGG-11', 'Fashion MNIST AlexNet', 'Fashion MNIST VGG-11', 'CIFAR-100 ResNet-18']
num_metrics = len(metrics)

# 获取方法名称和 Alpha 值
methods = df['Method'].unique()
alphas = df['Alpha'].unique()

# 创建雷达图的角度
angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
angles += angles[:1]

# 创建子图
fig, axs = plt.subplots(1, 3, figsize=(18, 6), subplot_kw=dict(polar=True))

# 不同 alpha 的颜色
alpha_colors = {0.1: 'blue', 0.2: 'green', 0.3: 'red'}

# 遍历每个 alpha 并绘制子图
for i, alpha in enumerate(alphas):
    ax = axs[i]
    for method in methods:
        # 获取该方法在特定 alpha 下的表现数据
        method_data = df[(df['Method'] == method) & (df['Alpha'] == alpha)]
        values = method_data[metrics].values.flatten().tolist()
        values += values[:1]  # 闭合图形
        
        # 绘制雷达图曲线
        ax.plot(angles, values, label=method, linewidth=2)
        ax.fill(angles, values, alpha=0.1)
    
    # 设置子图的标签和标题
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics, fontsize=12)
    ax.set_yticklabels([])  # 隐藏y轴标签
    ax.set_title(f'Alpha = {alpha}', size=14, color='black', position=(0.5, 1.1), weight='bold')

# 添加图例
axs[1].legend(loc='upper right', bbox_to_anchor=(1.3, 1.05), fontsize=10)

# 设置全局标题
plt.suptitle('Method Performance across Different Alphas', size=16, weight='bold', y=1.05)

# 显示图形
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 32.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 33.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 33.84]
}

# 创建DataFrame
df = pd.DataFrame(data)

# 方法的颜色方案，确保不同方法有不同颜色
method_colors = {
    'FedAvg': '#1f77b4', 'FedProx': '#ff7f0e', 'VRL-SGD': '#2ca02c', 'FedNova': '#d62728',
    'FedAdagrad': '#9467bd', 'FedYogi': '#8c564b', 'FedAdam': '#e377c2', 'CriticalFL': '#7f7f7f', 'CLPS-CLIPFed': '#bcbd22'
}

# 创建雷达图的角度
angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
angles += angles[:1]

# 创建子图
fig, axs = plt.subplots(1, 3, figsize=(18, 6), subplot_kw=dict(polar=True))

# 遍历每个 alpha 并绘制子图
for i, alpha in enumerate(alphas):
    ax = axs[i]
    for method in methods:
        # 获取该方法在特定 alpha 下的表现数据
        method_data = df[(df['Method'] == method) & (df['Alpha'] == alpha)]
        values = method_data[metrics].values.flatten().tolist()
        values += values[:1]  # 闭合图形
        
        # 绘制雷达图曲线，不同方法使用不同颜色
        ax.plot(angles, values, label=method, linewidth=2, color=method_colors[method])
        ax.fill(angles, values, alpha=0.1, color=method_colors[method])
    
    # 设置子图的标签和标题
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics, fontsize=12)
    ax.set_yticklabels([])  # 隐藏y轴标签
    ax.set_title(f'Alpha = {alpha}', size=14, color='black', position=(0.5, 1.1), weight='bold')

# 添加图例
axs[1].legend(loc='upper right', bbox_to_anchor=(1.3, 1.05), fontsize=10)

# 设置全局标题
plt.suptitle('Method Performance across Different Alphas', size=16, weight='bold', y=1.05)

# 调整布局，保存高清图片
plt.tight_layout()
plt.savefig('method_performance_across_alphas.png', dpi=300, bbox_inches='tight')  # 保存为高清PNG图像

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 33.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 34.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 34.84]
}

# 创建DataFrame
df = pd.DataFrame(data)

# 方法的颜色方案，确保不同方法有不同颜色
method_colors = {
    'FedAvg': '#1f77b4', 'FedProx': '#ff7f0e', 'VRL-SGD': '#2ca02c', 'FedNova': '#d62728',
    'FedAdagrad': '#9467bd', 'FedYogi': '#8c564b', 'FedAdam': '#e377c2', 'CriticalFL': '#7f7f7f', 'CLPS-CLIPFed': '#bcbd22'
}

# 创建雷达图的角度
angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
angles += angles[:1]

# 创建子图
fig, axs = plt.subplots(1, 3, figsize=(18, 6), subplot_kw=dict(polar=True))

# 遍历每个 alpha 并绘制子图
for i, alpha in enumerate(alphas):
    ax = axs[i]
    for method in methods:
        # 获取该方法在特定 alpha 下的表现数据
        method_data = df[(df['Method'] == method) & (df['Alpha'] == alpha)]
        values = method_data[metrics].values.flatten().tolist()
        values += values[:1]  # 闭合图形
        
        # 绘制雷达图曲线，不同方法使用不同颜色
        ax.plot(angles, values, label=method, linewidth=2, color=method_colors[method])
        ax.fill(angles, values, alpha=0.1, color=method_colors[method])
    
    # 设置子图的标签和标题
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics, fontsize=12)
    ax.set_yticklabels([])  # 隐藏y轴标签
    ax.set_title(f'Alpha = {alpha}', size=14, color='black', position=(0.5, 1.1), weight='bold')

# 添加图例
axs[1].legend(loc='upper right', bbox_to_anchor=(1.3, 1.05), fontsize=10)

# 设置全局标题
# plt.suptitle('Method Performance across Different Alphas', size=16, weight='bold', y=1.05)

# 调整布局，保存高清图片
plt.tight_layout()
plt.savefig('method_performance_across_alphas.png', dpi=300, bbox_inches='tight')  # 保存为高清PNG图像

# 显示图形
plt.show()

# %% [markdown]
# # 加上刻度

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 33.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 34.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 34.84]
}

# 创建DataFrame
df = pd.DataFrame(data)

# 定义需要对比的指标（即雷达图的标签）
metrics = ['CIFAR-10 AlexNet', 'CIFAR-10 VGG-11', 'Fashion MNIST AlexNet', 'Fashion MNIST VGG-11', 'CIFAR-100 ResNet-18']
num_metrics = len(metrics)

# 定义不同的 alpha 值
alphas = [0.1, 0.2, 0.3]

# 定义参与对比的方法
methods = ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed']

# 方法的颜色方案，确保不同方法有不同颜色
method_colors = {
    'FedAvg': '#1f77b4', 'FedProx': '#ff7f0e', 'VRL-SGD': '#2ca02c', 'FedNova': '#d62728',
    'FedAdagrad': '#9467bd', 'FedYogi': '#8c564b', 'FedAdam': '#e377c2', 'CriticalFL': '#7f7f7f', 'CLPS-CLIPFed': '#bcbd22'
}

# 创建雷达图的角度
angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
angles += angles[:1]

# 创建子图
fig, axs = plt.subplots(1, 3, figsize=(18, 6), subplot_kw=dict(polar=True))

# 遍历每个 alpha 并绘制子图
for i, alpha in enumerate(alphas):
    ax = axs[i]
    for method in methods:
        # 获取该方法在特定 alpha 下的表现数据
        method_data = df[(df['Method'] == method) & (df['Alpha'] == alpha)]
        values = method_data[metrics].values.flatten().tolist()
        values += values[:1]  # 闭合图形
        
        # 绘制雷达图曲线，不同方法使用不同颜色
        ax.plot(angles, values, label=method, linewidth=2, color=method_colors[method])
        ax.fill(angles, values, alpha=0.1, color=method_colors[method])
    
    # 设置子图的标签和标题
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics, fontsize=12)
    ax.set_yticklabels([])  # 隐藏y轴标签
    ax.set_title(f'Alpha = {alpha}', size=14, color='black', position=(0.5, 1.1), weight='bold')

# 添加图例
axs[1].legend(loc='upper right', bbox_to_anchor=(1.3, 1.05), fontsize=10)

# 设置全局标题
# plt.suptitle('Method Performance across Different Alphas', size=16, weight='bold', y=1.05)

# 调整布局，保存高清图片
plt.tight_layout()
plt.savefig('method_performance_across_alphas1.png', dpi=300, bbox_inches='tight')  # 保存为高清PNG图像

# 显示图形
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# 准备数据
data = {
    'Method': ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed'] * 3,
    'Alpha': [0.1] * 9 + [0.2] * 9 + [0.3] * 9,
    'CIFAR-10 AlexNet': [25.25, 27.19, 26.45, 25.92, 26.01, 27.03, 27.39, 34.66, 39.27,
                         35.74, 35.26, 35.66, 35.91, 36.34, 36.44, 37.08, 38.33, 46.56,
                         38.82, 36.72, 39.78, 38.75, 40.61, 40.58, 40.19, 41.94, 49.29],
    'CIFAR-10 VGG-11': [25.43, 25.97, 26.74, 25.53, 24.75, 26.27, 27.38, 30.53, 43.36,
                        42.26, 40.41, 41.56, 41.03, 43.35, 43.87, 45.73, 44.22, 53.87,
                        43.43, 41.12, 43.67, 43.86, 45.62, 45.17, 46.99, 46.61, 55.78],
    'Fashion MNIST AlexNet': [47.53, 47.53, 43.67, 49.45, 48.68, 47.88, 48.11, 55.77, 70.57,
                              49.61, 50.48, 49.12, 49.48, 49.42, 50.76, 50.68, 58.45, 71.30,
                              57.75, 54.41, 56.54, 55.80, 60.27, 60.55, 62.07, 62.90, 71.98],
    'Fashion MNIST VGG-11': [51.92, 52.36, 53.28, 50.67, 55.92, 55.32, 55.67, 58.76, 84.24,
                             65.79, 65.16, 66.95, 67.67, 69.33, 71.03, 70.68, 70.96, 87.03,
                             67.77, 66.53, 68.27, 68.26, 70.89, 72.39, 72.81, 72.04, 87.88],
    'CIFAR-100 ResNet-18': [28.28, 27.83, 28.57, 28.76, 29.21, 28.94, 28.57, 31.18, 33.35,
                            30.71, 30.65, 30.76, 30.82, 32.37, 32.18, 31.85, 32.54, 34.14,
                            31.76, 31.77, 31.58, 31.88, 32.78, 32.91, 32.58, 32.95, 34.84]
}

# 创建DataFrame
df = pd.DataFrame(data)

# 定义需要对比的指标（即雷达图的标签）
metrics = ['CIFAR-10 AlexNet', 'CIFAR-10 VGG-11', 'Fashion MNIST AlexNet', 'Fashion MNIST VGG-11', 'CIFAR-100 ResNet-18']
num_metrics = len(metrics)

# 定义不同的 alpha 值
alphas = [0.1, 0.2, 0.3]

# 定义参与对比的方法
methods = ['FedAvg', 'FedProx', 'VRL-SGD', 'FedNova', 'FedAdagrad', 'FedYogi', 'FedAdam', 'CriticalFL', 'CLPS-CLIPFed']

# 方法的颜色方案，确保不同方法有不同颜色
method_colors = {
    'FedAvg': '#1f77b4', 'FedProx': '#ff7f0e', 'VRL-SGD': '#2ca02c', 'FedNova': '#d62728',
    'FedAdagrad': '#9467bd', 'FedYogi': '#8c564b', 'FedAdam': '#e377c2', 'CriticalFL': '#7f7f7f', 'CLPS-CLIPFed': '#bcbd22'
}

# 创建雷达图的角度
angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
angles += angles[:1]

# 创建子图
fig, axs = plt.subplots(1, 3, figsize=(18, 6), subplot_kw=dict(polar=True))

# 定义刻度值，假设最大值为100，可以根据实际情况调整
num_ticks = 5  # 你想要多少个圈
max_value = 100  # 可以根据实际数据调整最大值
tick_values = np.linspace(0, max_value, num_ticks + 1)  # 创建刻度值，包括最大值
tick_labels = [f'{int(v)}' for v in tick_values]  # 格式化刻度标签为整数

# 遍历每个 alpha 并绘制子图
for i, alpha in enumerate(alphas):
    ax = axs[i]
    for method in methods:
        # 获取该方法在特定 alpha 下的表现数据
        method_data = df[(df['Method'] == method) & (df['Alpha'] == alpha)]
        values = method_data[metrics].values.flatten().tolist()
        values += values[:1]  # 闭合图形
        
        # 绘制雷达图曲线，不同方法使用不同颜色
        ax.plot(angles, values, label=method, linewidth=2, color=method_colors[method])
        ax.fill(angles, values, alpha=0.1, color=method_colors[method])
    
    # 设置子图的标签和标题
    ax.set_xticks(angles[:-1])
    ax.set_xticklabels(metrics, fontsize=12)
    
    # 设置每一圈的刻度和标签
    ax.set_yticks(tick_values)  # 设置 y 轴的刻度
    ax.set_yticklabels(tick_labels, fontsize=10)  # 设置刻度标签
    
    ax.set_title(f'α = {alpha}', size=14, color='black', position=(0.5, 1.1), weight='bold')

# 添加图例
axs[1].legend(loc='upper right', bbox_to_anchor=(1.3, 1.05), fontsize=10)

# 设置全局标题
# plt.suptitle('Method Performance across Different Alphas', size=16, weight='bold', y=1.05)

# 调整布局，保存高清图片
plt.tight_layout()
plt.savefig('paperImages/method_performance_across_alphas_with_ticks.png', dpi=300, bbox_inches='tight')  # 保存为高清PNG图像

# 显示图形
plt.show()
